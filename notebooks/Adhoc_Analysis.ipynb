-- %%
select * from retail_sales.raw.orders

-- %%
select * from retail_sales.raw.products

-- %%
Products --> 

1. product_id is not null
2. price_per_product is not null and > 0
3. category is not null
4. sub_category is not null
5. product_name is not null
6. state is not null
7. state is a valid state
8. product_id is unique

Orders --> 

1. order_id is not null
2. order_date is not null
3. order_customer_id is not null
4. order_status is not null
5. product_id should be present in products table
6. order_id is unique
7. order_date is not in the future
8. order_customer_id is unique
9. order_status is one of 'PENDING', 'APPROVED', 'CANCELLED'
10. order quantity should not be zero
11. order date should in format yyyy-mm-dd
12. ship date >= order date
13. discount must be between 0 and 1
14. profit must be numeric and not null
15. ship mode should be one of 'Standard Class', 'Second Class', 'First Class', 'Same Day'
16. customer id should be present in customer tabel and customer name should not be null
17. customer id should be unique
18. customer segment should be one of 'Home Office', 'Corporate', 'Consumer', 'Channel Partners'

-- %%
select * from retail_sales.quality.data_quality_rules
