-- %% [markdown]
-- Profit by Year

-- %%
SELECT
    order_year,
    ROUND(
        SUM(total_profit),
        2
    ) AS total_profit
FROM retail_sales.analytics
    .profit_by_year_category_subcategory_customer
GROUP BY
    order_year
ORDER BY
    order_year;

-- %% [markdown]
-- Profit by Year and Product Category

-- %%
SELECT
    order_year,
    category AS product_category,
    ROUND(
        SUM(total_profit),
        2
    ) AS total_profit
FROM retail_sales.analytics
    .profit_by_year_category_subcategory_customer
GROUP BY
    order_year,
    category
ORDER BY
    order_year,
    product_category;

-- %% [markdown]
-- Profit by Customer

-- %%
SELECT
    customer_id,
    customer_name,
    ROUND(
        SUM(total_profit),
        2
    ) AS total_profit
FROM retail_sales.analytics
    .profit_by_year_category_subcategory_customer
GROUP BY
    customer_id,
    customer_name
ORDER BY
    total_profit DESC
LIMIT 20;

-- %% [markdown]
-- Profit by Customer and Year

-- %%
SELECT
    customer_id,
    customer_name,
    order_year,
    ROUND(
        SUM(total_profit),
        2
    ) AS total_profit
FROM retail_sales.analytics
    .profit_by_year_category_subcategory_customer
GROUP BY
    customer_id,
    customer_name,
    order_year
ORDER BY
    order_year,
    total_profit DESC
LIMIT 20;
